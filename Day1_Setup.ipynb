# %% [markdown]
# <a href="https://colab.research.google.com/github/23A91A1234/Backend/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid categorizes AI competencies from foundational to highly specialized. Here's a summary in 4 points:
#
# *   **AI Literacy & Application:** Understanding basic AI concepts, data literacy, and the ability to use existing AI tools and services (e.g., using AI-powered software, understanding model outputs).
# *   **AI Development & Engineering:** Skills in building, training, and deploying machine learning models, requiring coding, data preprocessing, and framework proficiency.
# *   **AI Research & Science:** Involves inventing new AI algorithms, advancing theoretical understanding, and pushing the boundaries of AI capabilities.
# *   **AI Strategy & Leadership:** Focuses on defining AI vision, ethics, policy, and integrating AI solutions into business and societal strategy.
